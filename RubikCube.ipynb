# %% [markdown]
# <a href="https://colab.research.google.com/github/everestso/Summer24/blob/main/RubikCube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model 1

# %%
import numpy as np

class RubiksCube:
    def __init__(self):
        # Initialize a solved Rubik's Cube
        self.cube = np.array([
            [['W']*3]*3,  # Top face
            [['O']*3]*3,  # Left face
            [['G']*3]*3,  # Front face
            [['R']*3]*3,  # Right face
            [['B']*3]*3,  # Back face
            [['Y']*3]*3   # Bottom face
        ])

    def rotate_face(self, face):
        # Rotate a face 90 degrees clockwise
        self.cube[face] = np.rot90(self.cube[face], -1)

    def get_state(self):
        # Return the current state of the cube
        return self.cube

    def print_cube(self):
        # Print the cube in a human-readable format
        def print_face(face):
            for row in face:
                print(' '.join(row))

        print("Top Face:")
        print_face(self.cube[0])

        print("Left Face:")
        print_face(self.cube[1])

        print("Front Face:")
        print_face(self.cube[2])

        print("Right Face:")
        print_face(self.cube[3])

        print("Back Face:")
        print_face(self.cube[4])

        print("Bottom Face:")
        print_face(self.cube[5])

# Example usage
cube = RubiksCube()
print("Initial state:")
cube.print_cube()
cube.rotate_face(0)  # Rotate the top face
print("\nState after rotating top face:")
cube.print_cube()
# Out:
# Initial state:
# Top Face:
# W W W
# W W W
# W W W
# Left Face:
# O O O
# O O O
# O O O
# Front Face:
# G G G
# G G G
# G G G
# Right Face:
# R R R
# R R R
# R R R
# Back Face:
# B B B
# B B B
# B B B
# Bottom Face:
# Y Y Y
# Y Y Y
# Y Y Y
#
# State after rotating top face:
# Top Face:
# W W W
# W W W
# W W W
# Left Face:
# O O O
# O O O
# O O O
# Front Face:
# G G G
# G G G
# G G G
# Right Face:
# R R R
# R R R
# R R R
# Back Face:
# B B B
# B B B
# B B B
# Bottom Face:
# Y Y Y
# Y Y Y
# Y Y Y

# %% [markdown]
# # Model 2

# %%
import numpy as np

class RubiksCube:
    def __init__(self):
        # Initialize a solved Rubik's Cube
        self.cube = np.array([
            [['W']*3]*3,  # Top face
            [['O']*3]*3,  # Left face
            [['G']*3]*3,  # Front face
            [['R']*3]*3,  # Right face
            [['B']*3]*3,  # Back face
            [['Y']*3]*3   # Bottom face
        ])

    def rotate_face(self, face):
        # Rotate a face 90 degrees clockwise
        self.cube[face] = np.rot90(self.cube[face], -1)

    def get_state(self):
        # Return the current state of the cube
        return self.cube

    def print_cube(self):
        # Print the cube in a human-readable format in a 3D "T" structure
        def print_face(face):
            for row in face:
                print(' '.join(row))

        top = self.cube[0]
        left = self.cube[1]
        front = self.cube[2]
        right = self.cube[3]
        back = self.cube[4]
        bottom = self.cube[5]

        # Print the cube in a "T" structure
        print("      Top")
        for row in top:
            print("      " + ' '.join(row))

        print("Left  Front  Right  Back")
        for i in range(3):
            print(' '.join(left[i]) + "   " + ' '.join(front[i]) + "   " + ' '.join(right[i]) + "   " + ' '.join(back[i]))

        print("      Bottom")
        for row in bottom:
            print("      " + ' '.join(row))

# Example usage
cube = RubiksCube()
print("Initial state:")
cube.print_cube()
cube.rotate_face(0)  # Rotate the top face
print("\nState after rotating top face:")
cube.print_cube()
# Out:
# Initial state:
#       Top
#       W W W
#       W W W
#       W W W
# Left  Front  Right  Back
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
#       Bottom
#       Y Y Y
#       Y Y Y
#       Y Y Y
#
# State after rotating top face:
#       Top
#       W W W
#       W W W
#       W W W
# Left  Front  Right  Back
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
#       Bottom
#       Y Y Y
#       Y Y Y
#       Y Y Y

# %% [markdown]
# # Model 3

# %%
import numpy as np

class RubiksCube:
    def __init__(self):
        # Initialize a solved Rubik's Cube
        self.cube = np.array([
            [['W']*3]*3,  # Top face
            [['O']*3]*3,  # Left face
            [['G']*3]*3,  # Front face
            [['R']*3]*3,  # Right face
            [['B']*3]*3,  # Back face
            [['Y']*3]*3   # Bottom face
        ])

    def rotate_face(self, face):
        # Rotate a face 90 degrees clockwise
        self.cube[face] = np.rot90(self.cube[face], -1)

    def get_state(self):
        # Return the current state of the cube
        return self.cube

    def print_cube(self):
        # Print the cube in a human-readable format in a 3D "T" structure
        def print_face(face):
            for row in face:
                print(' '.join(row))

        top = self.cube[0]
        left = self.cube[1]
        front = self.cube[2]
        right = self.cube[3]
        back = self.cube[4]
        bottom = self.cube[5]

        # Print the cube in a "T" structure without labels
        for row in top:
            print("      " + ' '.join(row))

        for i in range(3):
            print(' '.join(left[i]) + "   " + ' '.join(front[i]) + "   " + ' '.join(right[i]) + "   " + ' '.join(back[i]))

        for row in bottom:
            print("      " + ' '.join(row))

# Example usage
cube = RubiksCube()
print("Initial state:")
cube.print_cube()
cube.rotate_face(0)  # Rotate the top face
print("\nState after rotating top face:")
cube.print_cube()
# Out:
# Initial state:
#       W W W
#       W W W
#       W W W
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
#       Y Y Y
#       Y Y Y
#       Y Y Y
#
# State after rotating top face:
#       W W W
#       W W W
#       W W W
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
# O O O   G G G   R R R   B B B
#       Y Y Y
#       Y Y Y
#       Y Y Y

# %% [markdown]
# # Standard Moves
#
# The standard moves for the 3x3 Rubik's Cube are typically denoted using a notation system called "Singmaster notation." Each move is represented by a letter indicating a face to be rotated, possibly followed by a symbol to indicate the direction of the rotation. Here are the standard moves:
#
# 1. **U (Up)**: Rotate the top face 90 degrees clockwise.
# 2. **U' (U prime or U inverted)**: Rotate the top face 90 degrees counterclockwise.
# 3. **U2**: Rotate the top face 180 degrees.
#
# 4. **D (Down)**: Rotate the bottom face 90 degrees clockwise.
# 5. **D' (D prime or D inverted)**: Rotate the bottom face 90 degrees counterclockwise.
# 6. **D2**: Rotate the bottom face 180 degrees.
#
# 7. **L (Left)**: Rotate the left face 90 degrees clockwise.
# 8. **L' (L prime or L inverted)**: Rotate the left face 90 degrees counterclockwise.
# 9. **L2**: Rotate the left face 180 degrees.
#
# 10. **R (Right)**: Rotate the right face 90 degrees clockwise.
# 11. **R' (R prime or R inverted)**: Rotate the right face 90 degrees counterclockwise.
# 12. **R2**: Rotate the right face 180 degrees.
#
# 13. **F (Front)**: Rotate the front face 90 degrees clockwise.
# 14. **F' (F prime or F inverted)**: Rotate the front face 90 degrees counterclockwise.
# 15. **F2**: Rotate the front face 180 degrees.
#
# 16. **B (Back)**: Rotate the back face 90 degrees clockwise.
# 17. **B' (B prime or B inverted)**: Rotate the back face 90 degrees counterclockwise.
# 18. **B2**: Rotate the back face 180 degrees.
#
# ### Notation Summary
#
# - **U**: Up face
# - **D**: Down face
# - **L**: Left face
# - **R**: Right face
# - **F**: Front face
# - **B**: Back face
# - **'**: Indicates a 90-degree counterclockwise rotation
# - **2**: Indicates a 180-degree rotation
#
# ### Example
#
# - **U**: Rotate the top face 90 degrees clockwise.
# - **R'**: Rotate the right face 90 degrees counterclockwise.
# - **F2**: Rotate the front face 180 degrees.
#
# Understanding these moves is crucial for solving the Rubik's Cube and for implementing algorithms in code.
